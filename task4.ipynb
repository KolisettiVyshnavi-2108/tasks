# %%
import numpy as np
from scipy.signal import correlate2d
master = np.loadtxt("mel_spectrogram.csv", delimiter=",")
M, N = master.shape
submatrix_files = [
    "submatrix_2.csv",
    "submatrix_2_variant_1.csv",
    "submatrix_2_variant_2.csv",
    "submatrix_2_variant_3.csv",
    "submatrix_2_variant_4.csv"
]
print("Master matrix shape:", master.shape)
for file in submatrix_files:
    sub = np.loadtxt(file, delimiter=",")
    m, n = sub.shape
    sub_norm = sub / np.linalg.norm(sub)
    master_norm = master / np.linalg.norm(master)
    corr = correlate2d(master_norm, sub_norm, mode="valid")
    i, j = np.unravel_index(np.argmax(corr), corr.shape)
    best_score = corr[i, j]
    deviation_percent = (1 - best_score) * 100
    print("\nFile:", file)
    print("Start Row :", i)
    print("End Row   :", i + m - 1)
    print("Start Col :", j)
    print("End Col   :", j + n - 1)
    print("Similarity score :", best_score)
    print("Deviation (%)    :", deviation_percent)
# Out:
# Master matrix shape: (128, 466)
#
# File: submatrix_2.csv
# Start Row : 0
# End Row   : 127
# Start Col : 314
# End Col   : 343
# Similarity score : 0.27425873706459575
# Deviation (%)    : 72.57412629354043
#
# File: submatrix_2_variant_1.csv
# Start Row : 0
# End Row   : 127
# Start Col : 314
# End Col   : 343
# Similarity score : 0.2742566482655866
# Deviation (%)    : 72.57433517344134
#
# File: submatrix_2_variant_2.csv
# Start Row : 0
# End Row   : 127
# Start Col : 314
# End Col   : 343
# Similarity score : 0.27420578125407213
# Deviation (%)    : 72.57942187459278
#
# File: submatrix_2_variant_3.csv
# Start Row : 0
# End Row   : 127
# Start Col : 313
# End Col   : 342
# Similarity score : 0.27221798714436163
# Deviation (%)    : 72.77820128556384
#
# File: submatrix_2_variant_4.csv
# Start Row : 0
# End Row   : 127
# Start Col : 313
# End Col   : 342
# Similarity score : 0.2665490730957258
# Deviation (%)    : 73.34509269042742
